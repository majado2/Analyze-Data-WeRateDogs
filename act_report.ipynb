# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ### Summary of my journey in data cleaning:
#
# - Determine which rows do not contain get requests
# - Also by dropping columns that contain many blank values
# - Also, you have merged the columns('doggo', 'floofer', 'pupper', 'puppo') into one field
# - Also, I fixed the types of columns within the ratio
# - I linked the connection between them and know the connection
# - I browse the pictures
# - I finally had one clean schedule to work on

# %% [markdown]
# ### Brief summary of what I found:
# First: How do users interact with the content of the tweets, and does the content have an effect on the interaction of users?
# From this idea, I looked first, are there more likes or retweets? Indeed, I find more likes. This gives a preliminary view of the behavior of users

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >And through the initial conclusion Badr, we have an idea whether the pictures are more interactive or the video, and indeed it appeared that the video is more interactive than the pictures (by liking or retweeting)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > From this idea, I decided to check the ratings. Are the video ratings higher or the pictures? Indeed, through the numbers, I noticed that the video ratings are higher.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >To clearly show that the video is more interactive and twitter than the pictures, and that the type of content is influential in interaction and evaluation
